# %%
#vae

# %%
ls -l /content/drive/MyDrive/ColabNotebooks/2ACIIDS2024_CL4Rec-main/
# Out:
# total 3325
# drwx------ 2 root root    4096 Dec 11 10:19 data_loader/
# drwx------ 2 root root    4096 Dec 11 10:19 datasets/
# -rw------- 1 root root     203 Dec  8 13:25 huong_dan_chay.txt
# -rw------- 1 root root    7341 Aug 17  2024 main_ae_raw_multi_domain.py
# -rw------- 1 root root   10111 Aug 17  2024 main_ae_with_ufo_space_multi_domain.py
# -rw------- 1 root root   11818 Aug 17  2024 main_graph_bi_interaction_multi_domain.py
# -rw------- 1 root root   17725 Aug 17  2024 main_graph_bi_interaction_with_ufo_space.py
# -rw------- 1 root root    9168 Aug 17  2024 mask_optimization_double_hard.py
# -rw------- 1 root root    9757 Aug 17  2024 mask_optimization_for_vae.py
# -rw------- 1 root root   11039 Aug 17  2024 mask_optimization_ufo_space_7.py
# drwx------ 2 root root    4096 Dec 11 10:19 ml-100k/
# -rw------- 1 root root   95276 Aug 17  2024 ml_100k_eda.ipynb
# drwx------ 2 root root    4096 Dec 11 10:19 model/
# -rw------- 1 root root  275249 Aug 17  2024 paper_193.pdf
# ...

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !python /MyDrive/ColabNotebooks/2ACIIDS2024_CL4Rec-main/main_ae_with_ufo_space_multi_domain.py --data_name ml_100k_action_fantasy --limits 0.5,0.5 --folder_save_model VAE_MULTI_DOMAIN --task_ids 0,1 --use_task_mask 1 --n_epochs 10 --lr 1e-3 --epoch_not_binary 9
# Out:
# python3: can't open file '/MyDrive/ColabNotebooks/2ACIIDS2024_CL4Rec-main/main_ae_with_ufo_space_multi_domain.py': [Errno 2] No such file or directory

# %%
# !python main_ae_with_ufo_space_multi_domain.py --data_name ml_100k_action_fantasy --limits 0.6,0.6 --folder_save_model VAE_MULTI_DOMAIN --task_ids 1,0 --use_task_mask 0 --n_epochs 10 --lr 1e-3
# Out:
#      uid      sid
# 0      2  281 308
# 1      3      181
# 2      4      260
# 3      5  453 423
# 4      6   28 423
# ..   ...      ...
# 932  939  254 411
# 933  940      879
# 934  941      147
# 935  942  174 423
# 936  943   234 72
#
# [937 rows x 2 columns]
# get data success
# start training
# epoch 0 | test score task 1: recall@50: 0.8630
# epoch 0 | test score all task: recall@50: 0.8630
# epoch 1 | test score task 1: recall@50: 0.9609
# epoch 1 | test score all task: recall@50: 0.9609
# epoch 2 | test score task 1: recall@50: 1.0000
# epoch 2 | test score all task: recall@50: 1.0000
# epoch 3 | test score task 1: recall@50: 1.0000
# epoch 3 | test score all task: recall@50: 1.0000
# epoch 4 | test score task 1: recall@50: 1.0000
# epoch 4 | test score all task: recall@50: 1.0000
# epoch 5 | test score task 1: recall@50: 1.0000
# epoch 5 | test score all task: recall@50: 1.0000
# epoch 6 | test score task 1: recall@50: 1.0000
# ...

# %%
# !python main_ae_with_ufo_space_multi_domain.py --data_name ml_100k_action_fantasy --limits 0.6,0.6 --folder_save_model VAE_MULTI_DOMAIN --task_ids 0,1 --use_task_mask 1 --n_epochs 10 --lr 1e-3 --use_task_mask_for_gradient_protecting 0  --epoch_not_binary 9
# Out:
#      uid      sid
# 0      2  281 308
# 1      3      181
# 2      4      260
# 3      5  453 423
# 4      6   28 423
# ..   ...      ...
# 932  939  254 411
# 933  940      879
# 934  941      147
# 935  942  174 423
# 936  943   234 72
#
# [937 rows x 2 columns]
# get data success
# start training
# epoch 0 | test score task 0: recall@50: 0.6457
# epoch 0 | test score all task: recall@50: 0.6457
# epoch 1 | test score task 0: recall@50: 0.7263
# epoch 1 | test score all task: recall@50: 0.7263
# epoch 2 | test score task 0: recall@50: 0.7615
# epoch 2 | test score all task: recall@50: 0.7615
# epoch 3 | test score task 0: recall@50: 0.7866
# epoch 3 | test score all task: recall@50: 0.7866
# epoch 4 | test score task 0: recall@50: 0.7705
# epoch 4 | test score all task: recall@50: 0.7705
# epoch 5 | test score task 0: recall@50: 0.7882
# epoch 5 | test score all task: recall@50: 0.7882
# epoch 6 | test score task 0: recall@50: 0.8036
# ...

# %%
#graph-based

# %%
# !python main_graph_bi_interaction_with_ufo_space.py --data_name ml_100k --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --masking_train 1 --task_n_epochs "100,100" --task_ids "0,1" --limit 0.7 --limits 0.8,0.5 --use_two_loss_checkpoint 1 --folder_save_model GRAPH_BI_INTERACTION_WITH_UFO_SPACE_HARD_MASK_ONE_TASK_MASK_DRAMA_COMEDY --just_one_task_mask_for_users 1 --just_one_task_mask_for_items 1 --ensemble_learning 0 --epoch_not_binary_mask 3
# Out:
# All logs will be saved to trained_model/GRAPH_BI_INTERACTION_WITH_UFO_SPACE_HARD_MASK_ONE_TASK_MASK_DRAMA_COMEDY/ml_100k/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.001_pretrain0/log6.log
# cuda
# None
# The maximum of the number of clusters for all entities is 255
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# Max num interactions is 1
# User features is not existed
# Item features is not existed
# 1
# 2
# 3
# 2627
# 4
# [943, 1682]
# 1684
# [74]
# ---------------------------------SEP----------------------------------------------
# loz
# 5.302227e-05
# loz
# 0.0010604454
# loz
# 0.0002453639588120458
# loz
# 0.00016967126
# loz
# 0.0074231178
# loz
# 0.0014783578742394192
# loz
# 0.0029162248
# loz
# 0.05461294
# loz
# 0.018857079108342605
# loz
# 0.0039236476
# loz
# 0.18345705
# loz
# 0.04419830253028111
# loz
# 0.0039236476
# loz
# 0.07211029
# loz
# 0.024364287847005544
# loz
# 0.00407211
# ...

# %%
# !python main_graph_bi_interaction_with_ufo_space.py --data_name ml_100k --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --masking_train 1 --task_n_epochs "100,100" --task_ids "0,1" --limit 0.7 --limits 0.7,0.7 --use_two_loss_checkpoint 1 --folder_save_model GRAPH_BI_INTERACTION_WITH_UFO_SPACE_SOFT_MASK_ONE_TASK_MASK_DRAMA_COMEDY --just_one_task_mask_for_users 1 --just_one_task_mask_for_items 1 --ensemble_learning 0 --epoch_not_binary_mask 1000
# Out:
# All logs will be saved to trained_model/GRAPH_BI_INTERACTION_WITH_UFO_SPACE_SOFT_MASK_ONE_TASK_MASK_DRAMA_COMEDY/ml_100k/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.001_pretrain0/log0.log
# cuda
# None
# The maximum of the number of clusters for all entities is 255
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# Max num interactions is 1
# User features is not existed
# Item features is not existed
# 1
# 2
# 3
# 2627
# 4
# [943, 1682]
# 1684
# [74]
# ---------------------------------SEP----------------------------------------------
# loz
# 5.302227e-05
# loz
# 0.0010604454
# loz
# 0.0002453639588120458
# loz
# 0.00016967126
# loz
# 0.0074231178
# loz
# 0.0014783578742394192
# loz
# 0.0029162248
# loz
# 0.05461294
# loz
# 0.018857079108342605
# loz
# 0.0039236476
# loz
# 0.18345705
# loz
# 0.04419830253028111
# loz
# 0.00397667
# loz
# 0.07264051
# loz
# 0.02449701371417734
# loz
# 0.00407211
# loz
# ...

# %%
# !python main_graph_bi_interaction_with_ufo_space.py --data_name ml_100k --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --masking_train 1 --task_n_epochs "100,100" --task_ids "0,1" --limit 0.7 --limits 0.7,0.7 --use_two_loss_checkpoint 1 --folder_save_model GRAPH_BI_INTERACTION_WITH_UFO_SPACE_SOFT_MASK_NO_MASK_DRAMA_COMEDY --epoch_not_binary_mask 3 --use_task_mask 0 --just_one_task_mask_for_users 1 --just_one_task_mask_for_items 1 --ensemble_learning 0
# Out:
# All logs will be saved to trained_model/GRAPH_BI_INTERACTION_WITH_UFO_SPACE_SOFT_MASK_NO_MASK_DRAMA_COMEDY/ml_100k/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.001_pretrain0/log0.log
# cuda
# None
# The maximum of the number of clusters for all entities is 255
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# Max num interactions is 1
# User features is not existed
# Item features is not existed
# 1
# 2
# 3
# 2627
# 4
# [943, 1682]
# 1684
# [74]
# ---------------------------------SEP----------------------------------------------
# loz
# 0.002386002
# loz
# 0.04559915
# loz
# 0.013616429756541554
# loz
# 0.003626723
# loz
# 0.16861081
# loz
# 0.038090192272897075
# loz
# 0.0051961825
# loz
# 0.09597031
# loz
# 0.0321048723138085
# loz
# 0.005090137
# loz
# 0.23276776
# loz
# 0.05983901035454238
# loz
# 0.0065747616
# loz
# 0.117709436
# loz
# 0.043464256343316736
# loz
# 0.005535525
# loz
# 0.25344646
# ...

# %%
# !python main_graph_bi_interaction_with_ufo_space.py --data_name ml_100k --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --masking_train 1 --task_n_epochs "100,100" --task_ids "0,1" --limit 0.7 --limits 0.8,0.5 --use_two_loss_checkpoint 1 --folder_save_model GRAPH_BI_INTERACTION_WITH_UFO_SPACE_NO_TASK_MASK_FOR_GRADIENT_PROTECTING_NEW_DRAMvA_COMEDY --epoch_not_binary_mask 3 --just_one_task_mask_for_users 1 --just_one_task_mask_for_items 1 --ensemble_learning 0 --use_task_mask_for_gradient_protecting 0
# Out:
# All logs will be saved to trained_model/GRAPH_BI_INTERACTION_WITH_UFO_SPACE_NO_TASK_MASK_FOR_GRADIENT_PROTECTING_NEW_DRAMvA_COMEDY/ml_100k/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.001_pretrain0/log2.log
# cuda
# None
# The maximum of the number of clusters for all entities is 255
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# Max num interactions is 1
# User features is not existed
# Item features is not existed
# 1
# 2
# 3
# 2627
# 4
# [943, 1682]
# 1684
# [74]
# ---------------------------------SEP----------------------------------------------
# loz
# 5.302227e-05
# loz
# 0.0010604454
# loz
# 0.0002453639588120458
# loz
# 0.00016967126
# loz
# 0.0074231178
# loz
# 0.0014783578742394192
# loz
# 0.0029162248
# loz
# 0.05461294
# loz
# 0.018857079108342605
# loz
# 0.0039236476
# loz
# 0.18345705
# loz
# 0.04419830253028111
# loz
# 0.0039236476
# loz
# 0.07211029
# loz
# 0.024364287847005544
# loz
# ...

# %%
#mf

# %%
# !python main_graph_bi_interaction_with_ufo_space.py --data_name ml_100k --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --masking_train 1 --task_n_epochs "100,100" --task_ids "0,1" --limit 0.7 --limits 0.8,0.5 --use_two_loss_checkpoint 1 --folder_save_model GRAPH_BI_INTERACTION_WITH_UFO_SPACE_HARD_MASK_ONE_TASK_MASK_DRAMA_COMEDY_MF --just_one_task_mask_for_users 1 --just_one_task_mask_for_items 1 --ensemble_learning 0 --epoch_not_binary_mask 3 --mf 1
# Out:
# All logs will be saved to trained_model/GRAPH_BI_INTERACTION_WITH_UFO_SPACE_HARD_MASK_ONE_TASK_MASK_DRAMA_COMEDY_MF/ml_100k/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.001_pretrain0/log3.log
# cuda
# None
# The maximum of the number of clusters for all entities is 255
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# Max num interactions is 1
# User features is not existed
# Item features is not existed
# 1
# 2
# 3
# 2627
# 4
# [943, 1682]
# 1684
# [74]
# ---------------------------------SEP----------------------------------------------
# loz
# 0.0069459174
# loz
# 0.12672323
# loz
# 0.05286708501363179
# loz
# 0.004665959
# loz
# 0.21420997
# loz
# 0.07056841236272149
# loz
# 0.015588548
# loz
# 0.28844115
# loz
# 0.10984550259351218
# loz
# 0.009862142
# loz
# 0.45493108
# loz
# 0.14336001532858894
# loz
# 0.015111348
# loz
# 0.27730647
# loz
# 0.1116615763837903
# loz
# 0.010116648
# loz
# ...

# %%
# !python main_graph_bi_interaction_with_ufo_space.py --data_name ml_100k --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --masking_train 1 --task_n_epochs "100,100" --task_ids "0,1" --limit 0.7 --limits 0.7,0.5 --use_two_loss_checkpoint 1 --folder_save_model UFO_SPACE_8_SOFT_MASK_ONE_TASK_MASK_DRAMA_COMEDY_MF --just_one_task_mask_for_users 1 --just_one_task_mask_for_items 1 --ensemble_learning 0 --epoch_not_binary_mask 1000 --mf 1
# Out:
# All logs will be saved to trained_model/UFO_SPACE_8_SOFT_MASK_ONE_TASK_MASK_DRAMA_COMEDY_MF/ml_100k/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.001_pretrain0/log7.log
# cuda
# None
# The maximum of the number of clusters for all entities is 255
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# Max num interactions is 1
# User features is not existed
# Item features is not existed
# 1
# 2
# 3
# 2627
# 4
# [943, 1682]
# 1684
# [74]
# ---------------------------------SEP----------------------------------------------
# loz
# 0.0069459174
# loz
# 0.12672323
# loz
# 0.05286708501363179
# loz
# 0.004665959
# loz
# 0.21420997
# loz
# 0.07056841236272149
# loz
# 0.015588548
# loz
# 0.28844115
# loz
# 0.10984550259351218
# loz
# 0.009862142
# loz
# 0.45493108
# loz
# 0.14336001532858894
# loz
# 0.015111348
# loz
# 0.27730647
# loz
# 0.1116615763837903
# loz
# 0.010116648
# loz
# 0.46447507
# loz
# ...

# %%
# !python main_graph_bi_interaction_with_ufo_space.py --data_name ml_100k --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --masking_train 1 --task_n_epochs "100,100" --task_ids "0,1" --limit 0.7 --limits 0.7,0.7 --use_two_loss_checkpoint 1 --folder_save_model GRAPH_BI_INTERACTIONS_WITH_UFO_SPACE_NO_TASK_MASK_DRAMA_COMEDY_MF --epoch_not_binary_mask 3 --use_task_mask 0 --mf 1 --just_one_task_mask_for_users 1 --just_one_task_mask_for_items 1 --ensemble_learning 0
# Out:
# All logs will be saved to trained_model/GRAPH_BI_INTERACTIONS_WITH_UFO_SPACE_NO_TASK_MASK_DRAMA_COMEDY_MF/ml_100k/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.001_pretrain0/log0.log
# cuda
# None
# The maximum of the number of clusters for all entities is 255
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# Max num interactions is 1
# User features is not existed
# Item features is not existed
# 1
# 2
# 3
# 2627
# 4
# [943, 1682]
# 1684
# [74]
# ---------------------------------SEP----------------------------------------------
# loz
# 0.0069459174
# loz
# 0.12672323
# loz
# 0.05194444711981667
# loz
# 0.0045811236
# loz
# 0.21049841
# loz
# 0.06868495479301072
# loz
# 0.015429481
# loz
# 0.28579003
# loz
# 0.11094074873618841
# loz
# 0.009819724
# loz
# 0.45281017
# loz
# 0.1448237666227179
# loz
# 0.015323437
# loz
# 0.2826087
# loz
# 0.11285492285775128
# loz
# 0.010095439
# loz
# 0.46553552
# loz
# ...

# %%
# !python main_graph_bi_interaction_with_ufo_space.py --data_name ml_100k --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --masking_train 1 --task_n_epochs "100,100" --task_ids "0,1" --limit 0.7 --limits 0.8,0.5 --use_two_loss_checkpoint 1 --folder_save_model GRAPH_BI_INTERACTIONS_WITH_UFO_SPACE_NO_TASK_MASK_FOR_GRADIENT_PROTECTING_NEW_DRAMA_COMEDY_MF --epoch_not_binary_mask 3 --use_task_mask_for_gradient_protecting 0 --mf 1 --just_one_task_mask_for_users 1 --just_one_task_mask_for_items 1 --ensemble_learning 0
# Out:
# All logs will be saved to trained_model/GRAPH_BI_INTERACTIONS_WITH_UFO_SPACE_NO_TASK_MASK_FOR_GRADIENT_PROTECTING_NEW_DRAMA_COMEDY_MF/ml_100k/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.001_pretrain0/log0.log
# cuda
# None
# The maximum of the number of clusters for all entities is 255
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# Max num interactions is 1
# User features is not existed
# Item features is not existed
# 1
# 2
# 3
# 2627
# 4
# [943, 1682]
# 1684
# [74]
# ---------------------------------SEP----------------------------------------------
# loz
# 0.0069459174
# loz
# 0.12672323
# loz
# 0.05286708501363179
# loz
# 0.004665959
# loz
# 0.21420997
# loz
# 0.07056841236272149
# loz
# 0.015588548
# loz
# 0.28844115
# loz
# 0.10984550259351218
# loz
# 0.009862142
# loz
# 0.45493108
# loz
# 0.14336001532858894
# loz
# 0.015111348
# loz
# 0.27730647
# loz
# 0.1116615763837903
# loz
# ...

# %%
#compare to other baselines

# %%
#graph_bi_interactions

# %%
# !python main_graph_bi_interaction_multi_domain.py --data_name ml_100k --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --masking_train 1 --task_ids "0,1" --task_n_epochs "100,100" --n_epoch 200 --folder_save_model GRAPH_BI_INTERACTION_RAW_FOR_MULTI_DOMAIN
# Out:
# All logs will be saved to trained_model/GRAPH_BI_INTERACTION_RAW_FOR_MULTI_DOMAIN/ml_100k/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.001_pretrain0/log3.log
# cuda
# None
# The maximum of the number of clusters for all entities is 255
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# Max num interactions is 1
# User features is not existed
# Item features is not existed
# 1
# 2
# 3
# 2627
# 4
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# [943, 1682]
# 1684
# [74]
# ---------------------------------SEP----------------------------------------------
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# Task id 0
# No cold start
# ---------------------------------SEP----------------------------------------------
# Task id 1
# No cold start
# ...

# %%
#mf

# %%
# !python main_graph_bi_interaction_multi_domain.py --data_name ml_100k --use_pretrain 0 --cf_print_every 16 --kg_print_every 16 --evaluate_every 1 --Ks '[20,50]' --cf_batch_size 1024  --lr 1e-3 --masking_train 1 --task_ids "0,1" --task_n_epochs "100,100" --n_epoch 200 --folder_save_model MATRIX_FACTORIZATION_RAW_FOR_MULTI_DOMAIN --mf 1
# Out:
# All logs will be saved to trained_model/MATRIX_FACTORIZATION_RAW_FOR_MULTI_DOMAIN/ml_100k/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.001_pretrain0/log1.log
# cuda
# None
# The maximum of the number of clusters for all entities is 255
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# Max num interactions is 1
# User features is not existed
# Item features is not existed
# 1
# 2
# 3
# 2627
# 4
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# [943, 1682]
# 1684
# [74]
# ---------------------------------SEP----------------------------------------------
# [  1   1   1 ... 943 943 943]
# [0]
# [  1   2   2 ... 942 943 943]
# [0]
# [  1   1   1 ... 943 943 943]
# Task id 0
# No cold start
# ---------------------------------SEP----------------------------------------------
# Task id 1
# No cold start
# ...

# %%
#vae

# %%
# !python main_ae_raw_multi_domain.py --data_name ml_100k_action_fantasy --limits 0.6,0.6 --folder_save_model VAE_RAW_MULTI_DOMAIN --task_ids 0,1 --use_task_mask 1 --n_epochs 100 --lr 1e-3 --vae_using_ufo_space 0
# Out:
#      uid      sid
# 0      2  281 308
# 1      3      181
# 2      4      260
# 3      5  453 423
# 4      6   28 423
# ..   ...      ...
# 932  939  254 411
# 933  940      879
# 934  941      147
# 935  942  174 423
# 936  943   234 72
#
# [937 rows x 2 columns]
# get data success
# start training
# epoch 0 | test score task 0: recall@50: 0.2978
# epoch 0 | test score task 1: recall@50: 0.3209
# epoch 0 | test score all task: recall@50: 0.3093
# epoch 1 | test score task 0: recall@50: 0.4723
# epoch 1 | test score task 1: recall@50: 0.4139
# epoch 1 | test score all task: recall@50: 0.4431
# epoch 2 | test score task 0: recall@50: 0.5704
# epoch 2 | test score task 1: recall@50: 0.4217
# epoch 2 | test score all task: recall@50: 0.4961
# epoch 3 | test score task 0: recall@50: 0.6377
# epoch 3 | test score task 1: recall@50: 0.4198
# epoch 3 | test score all task: recall@50: 0.5287
# epoch 4 | test score task 0: recall@50: 0.6708
# epoch 4 | test score task 1: recall@50: 0.4022
# ...
